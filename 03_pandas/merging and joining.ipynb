# %%
import pandas as pd

employees = pd.DataFrame({
    "EmpID": [1, 2, 3],
    "Name": ["Alice", "Bob", "Charlie"],
    "DeptID": [10, 20, 30]
})

departments = pd.DataFrame({
    "DeptID": [10, 20, 40],
    "DeptName": ["HR", "Engineering", "Marketing"]
})

# %%
employees
# Out:
#    EmpID     Name  DeptID
# 0      1    Alice      10
# 1      2      Bob      20
# 2      3  Charlie      30

# %%
departments
# Out:
#    DeptID     DeptName
# 0      10           HR
# 1      20  Engineering
# 2      40    Marketing

# %%
pd.merge(employees, departments)
# Out:
#    EmpID   Name  DeptID     DeptName
# 0      1  Alice      10           HR
# 1      2    Bob      20  Engineering

# %%
pd.merge(employees, departments, how="left")
# Out:
#    EmpID     Name  DeptID     DeptName
# 0      1    Alice      10           HR
# 1      2      Bob      20  Engineering
# 2      3  Charlie      30          NaN

# %%
pd.merge(employees, departments, how="right")
# Out:
#    EmpID   Name  DeptID     DeptName
# 0    1.0  Alice      10           HR
# 1    2.0    Bob      20  Engineering
# 2    NaN    NaN      40    Marketing

# %%
pd.merge(employees, departments, how="outer")
# Out:
#    EmpID     Name  DeptID     DeptName
# 0    1.0    Alice      10           HR
# 1    2.0      Bob      20  Engineering
# 2    3.0  Charlie      30          NaN
# 3    NaN      NaN      40    Marketing

# %%
df1 = pd.DataFrame({"Name": ["Alice", "Bob"]})
df2 = pd.DataFrame({"Name": ["Charlie", "David"]})

concat_df = pd.concat([df1, df2])

# %%
concat_df["Name"]
# Out:
# 0      Alice
# 1        Bob
# 0    Charlie
# 1      David
# Name: Name, dtype: object

# %%
print(concat_df.columns)       # Check column names
print(concat_df.shape)         # See how many rows & cols
# Out:
# Index(['Name'], dtype='object')
# (4, 1)

# %%
concat_df.iloc[:, 0]  # Second 'Name' column
# Out:
# 0      Alice
# 1        Bob
# 0    Charlie
# 1      David
# Name: Name, dtype: object

# %%
concat_df
# Out:
#       Name
# 0    Alice
# 1      Bob
# 0  Charlie
# 1    David

# %%
concat_df_col_wise = pd.concat([df1, df2], axis=1)

# %%
concat_df_col_wise
# Out:
#     Name     Name
# 0  Alice  Charlie
# 1    Bob    David

# %%
concat_df_col_wise.iloc[:, 1]
# Out:
# 0    Charlie
# 1      David
# Name: Name, dtype: object

# %%
concat_df_col_wise["Name"]
# Out:
#     Name     Name
# 0  Alice  Charlie
# 1    Bob    David
