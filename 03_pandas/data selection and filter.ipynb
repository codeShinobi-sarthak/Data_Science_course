# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")

# %%
print(df)
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
type(df['Actor'])
# Out:
# pandas.core.series.Series

# %%
df["Year"]
# Out:
# 0     2023
# 1     2017
# 2     2016
# 3     2022
# 4     2018
# 5     2018
# 6     2018
# 7     2019
# 8     2019
# 9     2022
# 10    2017
# 11    2019
# Name: Year, dtype: int64

# %%
df.loc[3]
# Out:
# Actor                   Ranbir Kapoor
# Film                       Brahmastra
# Year                             2022
# Genre                         Fantasy
# BoxOffice(INR Crore)              431
# IMDb                              5.6
# Name: 3, dtype: object

# %%
df.iloc[3]
# Out:
# Actor                   Ranbir Kapoor
# Film                       Brahmastra
# Year                             2022
# Genre                         Fantasy
# BoxOffice(INR Crore)              431
# IMDb                              5.6
# Name: 3, dtype: object

# %%
df.loc[0:2, ["Actor", "Year"]]   # Rows 0 to 2, selected columns
# Out:
#             Actor  Year
# 0  Shah Rukh Khan  2023
# 1     Salman Khan  2017
# 2      Aamir Khan  2016

# %%
df.iloc[0:2, 0:2]              # Rows and cols by index position
# Out:
#             Actor             Film
# 0  Shah Rukh Khan          Pathaan
# 1     Salman Khan  Tiger Zinda Hai

# %%
df.at[5, "Actor"]       # Fast "label"-based access
# Out:
# 'Ayushmann Khurrana'

# %%
df.iat[5, 3]           # Fast "position"-based access
# Out:
# 'Thriller'

# %%
df[df["IMDb"] >= 8]
# Out:
#                  Actor                      Film  Year      Genre  \
# 2           Aamir Khan                    Dangal  2016  Biography
# 5   Ayushmann Khurrana                 Andhadhun  2018   Thriller
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019     Action
#
#     BoxOffice(INR Crore)  IMDb
# 2                   2024   8.4
# 5                    111   8.3
# 11                   342   8.2

# %%
df[(df["IMDb"] >= 5) & (df['Year'] > 2020)]
# Out:
#             Actor               Film  Year          Genre  \
# 0  Shah Rukh Khan            Pathaan  2023         Action
# 3   Ranbir Kapoor         Brahmastra  2022        Fantasy
# 9   Kartik Aaryan  Bhool Bhulaiyaa 2  2022  Horror Comedy
#
#    BoxOffice(INR Crore)  IMDb
# 0                  1050   7.2
# 3                   431   5.6
# 9                   266   5.9

# %%
df.query("Year > 2020 and Genre == 'Action'")
# Out:
#             Actor     Film  Year   Genre  BoxOffice(INR Crore)  IMDb
# 0  Shah Rukh Khan  Pathaan  2023  Action                  1050   7.2

# %%
rating_limit = 7
df.query("IMDb  > @rating_limit")
# Out:
#                  Actor                      Film  Year          Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023         Action
# 2           Aamir Khan                    Dangal  2016      Biography
# 5   Ayushmann Khurrana                 Andhadhun  2018       Thriller
# 6        Rajkummar Rao                     Stree  2018  Horror Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019         Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 2                   2024   8.4
# 5                    111   8.3
# 6                    180   7.5
# 11                   342   8.2
