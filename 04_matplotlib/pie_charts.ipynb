# %%
import matplotlib.pyplot as plt

# %%
# plt.style.available
plt.style.use("Solarize_Light2")  # Choose any style you like

# %%
# Data
labels = ["Sachin", "Sehwag", "Kohli", "Yuvraj"]
runs = [18000, 8000, 12000, 9500]

plt.title("Career Runs of Indian Batsmen")
# plt.pie(runs, labels=labels)
plt.pie(runs, labels=labels, wedgeprops={'edgecolor': 'black'})
# Out:
# ([<matplotlib.patches.Wedge at 0x22ee4b847d0>,
#   <matplotlib.patches.Wedge at 0x22ee4b84a50>,
#   <matplotlib.patches.Wedge at 0x22ee4b84cd0>,
#   <matplotlib.patches.Wedge at 0x22ee4b24550>],
#  [Text(0.408316888704146, 1.0214094763604684, 'Sachin'),
#   Text(-1.0706592615758088, 0.25236629252327625, 'Sehwag'),
#   Text(-0.5074755072212109, -0.9759449828604966, 'Kohli'),
#   Text(0.8899186414035474, -0.6465638496563697, 'Yuvraj')])

# %%
explode = [0.1, 1, 0, 0]  

plt.pie(runs, labels=labels, explode=explode)
plt.title("Exploded Pie Example")
# Out:
# Text(0.5, 1.0, 'Exploded Pie Example')

# %%
explode = [0.1, 0.2, 0, 0]  
plt.figure(figsize=(6,6))

plt.pie(runs, labels=labels, explode=explode, shadow=True, startangle=100, autopct='%1.2f%%',)
plt.title("Exploded Pie Example")
# Out:
# Text(0.5, 1.0, 'Exploded Pie Example')
