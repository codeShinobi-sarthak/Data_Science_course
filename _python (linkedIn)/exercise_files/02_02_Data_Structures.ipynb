# %% [markdown]
# # Data Structures

# %% [markdown]
# ## Lists

# %%
my_list = [1,2,3,4]
print(my_list)
# Out:
# [1, 2, 3, 4]

# %%
my_list = ['list', 'of', 'strings']

# %%
my_list = [1,'list', False, []]

# %%
my_list
# Out:
# [1, 'list', False, []]

# %%
my_list = [[1,2,3],[False, True], []]

# %%
len(my_list[1])
# Out:
# 2

# %% [markdown]
# ## Sets

# %%
my_set = {1,2,3,4,5}
print(my_set)
# Out:
# {1, 2, 3, 4, 5}

# %%
type(my_set)
# Out:
# set

# %%
len(my_set)
# Out:
# 5

# %%
my_set = {1,1,2,2}
len(my_set)
print(my_set)
# Out:
# {1, 2}

# %%
[1,2] == [2,1]
# Out:
# False

# %%
{1,2,3} == {3,2,1,1,1}
# Out:
# True

# %% [markdown]
# ## Tuples

# %%
my_tuple = (1,2,3)

# %%
len(my_tuple)
# Out:
# 3

# %%
(1,2) == (2,1)
# Out:
# False

# %%
my_list.append(6)
print(my_list)
# Out:
# [[1, 2, 3], [False, True], [], 4, 4, 6]

# %%
my_tuple.append(4)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [25], in <module>
# ----> 1 my_tuple.append(4)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
new_tuple = (2, 3, 4, 5)

# %%
type(new_tuple)
# Out:
# tuple

# %%
new_list = list(new_tuple)

# %%
type(new_list)
# Out:
# list

# %%
new_list.append(9)  # run two times so two 9's are showing
new_list
# Out:
# [2, 3, 4, 5, 9, 9]

# %% [markdown]
# ## Dictionaries

# %%
my_dictionary = {
    'apple': 'A red fruit', 
    'bear': 'A scary animal'
}

# %%
my_dictionary['apple']
# Out:
# 'A red fruit'

# %%
my_dictionary = {
    'apple': 'A red fruit', 
    'bear': 'A scary animal',
    'apple': 'Sometimes a green fruit'
}

# %%
my_dictionary['apple']
# Out:
# 'Sometimes a green fruit'

# %%
my_dictionary
# Out:
# {'apple': 'Sometimes a green fruit', 'bear': 'A scary animal'}
