# %% [markdown]
# ### Bytes

# %%
bytes(4)
# Out:
# b'\x00\x00\x00\x00'

# %%
smileyBytes = bytes('🙄', 'utf-8')
smileyBytes
# Out:
# b'\xf0\x9f\x99\x84'

# %%
smileyBytes.decode('utf-8')
# Out:
# '🙄'

# %%
smileyBytes = bytearray('🙄', 'utf-8')

# %%
smileyBytes
# Out:
# bytearray(b'\xf0\x9f\x99\x84')

# %%
smileyBytes[3] = int('85', 16)

# %%
smileyBytes.decode('utf-8')
# Out:
# '🙅'

# %%
b = b"sarthak"
print(tuple(b));
# Out:
# (115, 97, 114, 116, 104, 97, 107)

# %%
b_array = bytearray(b"hello")
b_array[0] = int('82', 16)
print(b_array)
# Out:
# bytearray(b'\x82ello')
